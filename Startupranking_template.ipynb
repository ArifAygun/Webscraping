# %% [markdown]
# <a href="https://colab.research.google.com/github/ArifAygun/Webscraping/blob/main/Startupranking_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.startupranking.com/startup/new'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36'
}

response = requests.get(url, headers=headers)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    results = []

    table = soup.select_one('body > div.wrapper.container > section:nth-child(1) > table > tbody')

    if table:
        rows = table.find_all('tr')  # Select all rows in the table

        for row in rows[:100]:  # Loop through the first 100 rows
            rank = row.select_one('td:nth-of-type(1)').text.strip()
            name = row.select_one('td:nth-of-type(2)').text.strip()
            score = row.select_one('td:nth-of-type(3)').text.strip()
            description = row.select_one('td:nth-of-type(4)').text.strip()
            country_image = row.select_one('td:nth-of-type(5) a:nth-of-type(1) img:nth-of-type(1)')
            country_name = country_image['title'].strip() if country_image else ""

            result_dict = {
                'Rank': rank,
                'Startup': name,
                'SR Score': score,
                'Description': description,
                'Country Rank': country_name
            }
            results.append(result_dict)

        df = pd.DataFrame(results)
    else:
        print("Table not found on the page.")
else:
    print("Failed to fetch the webpage. Status code:", response.status_code)

# %%
df
# Out:
#                        Rank Startup SR Score  \
# 0                   NeuroX1  12,858   17,231
# 1              Artwork Flow   3,964   34,958
# 2   Business Name Generator  19,334   10,979
# 3                   Noty.ai   2,877   39,936
# 4               RemoteDream  19,906    3,693
# ..                      ...     ...      ...
# 95                    Xerve   1,608   49,967
# 96        Instant Payday NV  16,354   14,616
# 97                ROOTCLOUD  19,966    3,521
# 98             Eternal Wigs   4,089   34,309
# 99            CBD Boxes Hub  17,446   13,723
#
#                                           Description    Country Rank
# 0   The new standard in computational neuroscience...   United States
# 1   Creative management powered by AI - \n        ...           India
# 2   Worlds Most Powerful Business Name Generator -...   United States
# 3   Make your meetings productive again - \n      ...   United States
# 4   Find & book the best hotels & hostels to work ...     Netherlands
# ..                                                ...             ...
# 95  India's No.1 Price Comparison Website - \n    ...           India
# 96  Get a Personal Loan Today - \n                ...   United States
# 97  Enabling Things, Connecting Future - \n       ...           China
# 98  Online brand for beautiful and affordable wigs...  United Kingdom
# 99  CBD Boxes Hub - \n                            ...   United States
#
# [100 rows x 5 columns]
