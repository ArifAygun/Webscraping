# %% [markdown]
# <a href="https://colab.research.google.com/github/ArifAygun/Webscraping/blob/main/Linkedin_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.linkedin.com/mynetwork/invite-connect/connections/'

page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html><body><code id="dust-var-isMobile" style="display: none"><!--false--></code>
# <code id="dust-var-i18nAgree" style="display: none"><!--"Agree & Join"--></code>
# <code id="dust-var-i18nContinue" style="display: none"><!--"Continue"--></code>
# <code id="dust-var-enabledTabLangMobile" style="display: none"><!--false--></code>
# <code id="dust-var-hasInlineErrors" style="display: none"><!--true--></code>
# <code id="dust-var-hasSinglePageHelpLink" style="display: none"><!--true--></code>
# <code id="dust-var-handleAvailTreatment" style="display: none"><!--""--></code>
# <code id="dust-var-isDomainCN" style="display: none"><!--false--></code>
# <code id="dust-var-isCountryCN" style="display: none"><!--false--></code>
# <meta content="d_registration-cold-join" name="pageKey"/>
# <!-- --> <meta content="en_US" name="locale"/>
# ...

# %%
pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.2 MB/s eta 0:00:00
# ...

# %%
from selenium import webdriver
import time
import pandas as pd
import os

from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Chrome(executable_path = "/Users/arifaygun/Desktop/chromedriver")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0757ab1035a2> in <cell line: 1>()
# ----> 1 driver = webdriver.Chrome(executable_path = "/Users/arifaygun/Desktop/chromedriver")
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'executable_path'
