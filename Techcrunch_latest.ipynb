# %% [markdown]
# <a href="https://colab.research.google.com/github/ArifAygun/Webscraping/blob/main/Techcrunch_latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bs4
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pprint import pprint

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Web_Scraping/Techcrunch/
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/Web_Scraping/Techcrunch

# %%
base_site = 'https://techcrunch.com/'
response = requests.get(base_site)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
html = response.content
pprint(html)

# %%
article_titles, article_contents, article_hrefs = [], [], []

for tag in soup.findAll("div", {"class": "post-block post-block--image post-block--unread"}):
    tag_header = tag.find("a", {"class": "post-block__title__link"})
    tag_content = tag.find("div", {"class": "post-block__content"})

    article_title = tag_header.get_text().strip()
    article_href = tag_header["href"]
    article_content = tag_content.get_text().strip()

    article_titles.append(article_title)
    article_contents.append(article_content)
    article_hrefs.append(article_href)

# %%
df = pd.DataFrame({"title": article_titles, "content": article_contents, "href": article_hrefs})
df.shape
# Out:
# (20, 3)

# %%
df
# Out:
#                                                 title  \
# 0   Kyle Vogt to discuss self-driving cars, AI, in...
# 1   E-commerce acquirer Benitago files for bankruptcy
# 2   Pitch Deck Teardown: Tanbii’s $1.5M pre-seed deck
# 3   Inalife’s digital legacy platform lets you pre...
# 4              What’s the opposite of a lean startup?
# 5   Lidl recalls Paw Patrol snacks after website o...
# 6   Korean internet giant Naver explores robotics,...
# 7   How the FBI took down the notorious Qakbot botnet
# 8   Google pulls popular but controversial live vi...
# 9   How to pitch me: 15 investors talk about what ...
# 10  Lawsuit alleges no due diligence in Amazon’s P...
# 11  Fisker confirms Foxconn will build its $29,900...
# 12  Biden offers $15.5B to boost battery and EV ma...
# 13  Robotics sales decline for second straight qua...
# 14   Texas cannot yet enforce ID checks on porn sites
# 15  Grayscale wins lawsuit against SEC, while the ...
# 16  Lowering costs nets Salesforce a profitable qu...
# 17  YouTube Music gets more social, adds comments ...
# 18  X plans to collect users’ biometric data, alon...
# 19  Forever 21 data breach affects half a million ...
#
#                                               content  \
# 0   Cruise, the self-driving subsidiary of General...
# 1   The move comes after the New York-based compan...
# 2   About a year ago, I tore down a pitch deck by ...
# 3   A new startup, Inalife, has created a digital ...
# 4   This is our Friday show, and we’re talking abo...
# 5   Supermarket giant Lidl has issued a recall of ...
# 6   In July last year, Naver, maker of the search ...
# 7   A global law enforcement operation this week t...
# 8   Google has removed popular but controversial l...
# 9   “I suggest reaching out right before Labor Day...
# 10  An institutional investor is suing Amazon and ...
# 11  EV startup Fisker revealed more details about ...
# 12  The United States Department of Energy is dedi...
# 13  Sooner or later, the numbers were going to con...
# 14  A Texas judge issued an injunction today to st...
# 15  If you’ve been dreaming about bitcoin spot ETF...
# 16  Salesforce had a better quarter than expected,...
# 17  YouTube Music redesigned its “Now Playing” scr...
# 18  X, formerly known as Twitter, will begin colle...
# 19  Clothing giant Forever 21 said a data breach e...
#
#                                                  href
# 0   https://techcrunch.com/2023/09/01/kyle-vogt-to...
# 1   https://techcrunch.com/2023/09/01/e-commerce-a...
# 2   https://techcrunch.com/2023/09/01/sample-pre-s...
# 3   https://techcrunch.com/2023/09/01/inalifes-dig...
# 4   https://techcrunch.com/2023/09/01/whats-the-op...
# 5   https://techcrunch.com/2023/09/01/lidl-recalls...
# 6   https://techcrunch.com/2023/09/01/korean-inter...
# 7   https://techcrunch.com/2023/09/01/fbi-qakbot-t...
# 8   https://techcrunch.com/2023/09/01/google-pulls...
# 9   https://techcrunch.com/2023/08/31/august-2023-...
# 10  https://techcrunch.com/2023/08/31/lawsuit-alle...
# 11  https://techcrunch.com/2023/08/31/fisker-confi...
# 12  https://techcrunch.com/2023/08/31/biden-offers...
# 13  https://techcrunch.com/2023/08/31/robotics-sal...
# 14  https://techcrunch.com/2023/08/31/texas-cannot...
# 15  https://techcrunch.com/2023/08/31/grayscale-wi...
# 16  https://techcrunch.com/2023/08/31/salesforce-s...
# 17  https://techcrunch.com/2023/08/31/youtube-musi...
# 18  https://techcrunch.com/2023/08/31/x-plans-to-c...
# 19  https://techcrunch.com/2023/08/31/forever-21-d...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    20 non-null     object
#  1   content  20 non-null     object
#  2   href     20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
df.to_csv('techcrunch_latest_artc.csv', index=False)
