# %% [markdown]
# <a href="https://colab.research.google.com/github/ArifAygun/Webscraping/blob/main/Largest_mining_companies_by_market_cap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Web_Scraping/Capterra/
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Web_Scraping/Capterra

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint

# %% [markdown]
# ## Making a get request

# %%
base_site = 'https://companiesmarketcap.com/manufacturing/largest-manufacturing-companies-by-market-cap/'
response = requests.get(base_site)
response
# Out:
# <Response [200]>

# %%
html = response.content
pprint(html)
# Out:
# (b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n<title>Largest manufacturing '
#  b'companies by Market Cap</title>\n<meta charset="utf-8" />\n<link rel="shor'
#  b'tcut icon" href="https://companiesmarketcap.com/favicon.ico" type="image/x-i'
#  b'con">\n<link rel="apple-touch-icon" sizes="57x57" href="/img/icons/apple-'
#  b'icon-57x57.png">\n<link rel="apple-touch-icon" sizes="60x60" href="/img/i'
#  b'cons/apple-icon-60x60.png">\n<link rel="apple-touch-icon" sizes="72x72" h'
#  b'ref="/img/icons/apple-icon-72x72.png">\n<link rel="apple-touch-icon" size'
#  b's="76x76" href="/img/icons/apple-icon-76x76.png">\n<link rel="apple-touch'
#  b'-icon" sizes="114x114" href="/img/icons/apple-icon-114x114.png">\n<link r'
#  b'el="apple-touch-icon" sizes="120x120" href="/img/icons/apple-icon-120x120.pn'
#  b'g">\n<link rel="apple-touch-icon" sizes="144x144" href="/img/icons/apple-'
#  b'icon-144x144.png">\n<link rel="apple-touch-icon" sizes="152x152" href="/i'
# ...

# %%
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <title>Largest manufacturing companies by Market Cap</title>
# <meta charset="utf-8"/>
# <link href="https://companiesmarketcap.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/img/icons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/img/icons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/img/icons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/icons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/img/icons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/img/icons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/img/icons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/img/icons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# ...
